# %%
import sys
import os
import pandas as pd
import json

# %%
module_path = os.path.abspath(os.path.join('..', 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Now import the function
from optimize_recipes import optimize_recipes

# Define paths
filtered_recipes_path = "../data/filtered_user_recipes.csv"
user_input_path = "../data/user_input.json"
optimized_recipes_path = "../data/optimized_recipes.csv"

# Load filtered recipes
if not pd.read_csv(filtered_recipes_path).empty:
    recipes_df = pd.read_csv(filtered_recipes_path)
    print("Filtered recipes loaded successfully!")
else:
    raise FileNotFoundError(f"Filtered recipes not found at {filtered_recipes_path}. Please run Step 3 first.")

# Load user input
if not pd.read_json(user_input_path).empty:
    with open(user_input_path, "r") as file:
        user_input = json.load(file)
    print("User input loaded successfully!")
else:
    raise FileNotFoundError(f"User input file not found at {user_input_path}. Please run Step 2 first.")

# print(recipes_df["nutrition"].head())
print(recipes_df.head())

# Optimize recipes
optimized_recipes = optimize_recipes(recipes_df, user_input)

# Save optimized recipes
optimized_recipes.to_csv(optimized_recipes_path, index=False)
print(f"Optimized recipes saved at: {optimized_recipes_path}")

# Display top 5 optimized recipes
print("\nTop 5 Optimized Recipes:")
print(optimized_recipes.head())
# Out:
# Filtered recipes loaded successfully!
# User input loaded successfully!
#        id                                        name  minutes  \
# 0  137739  arriba   baked winter squash mexican style       55
# 1   44061          amish  tomato ketchup  for canning      190
# 2   25274                       aww  marinated olives       15
# 3   43026                              chile rellenos       45
# 4   23850           cream  of cauliflower soup  vegan      110
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['weeknight', 'time-to-make', 'course', 'main-...
# 2  ['15-minutes-or-less', 'time-to-make', 'course...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['lactose', 'weeknight', 'time-to-make', 'cour...
#
#                                    nutrition  n_steps  \
# 0      [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1  [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
# 2   [380.7, 53.0, 7.0, 24.0, 6.0, 24.0, 6.0]        4
# 3   [94.0, 10.0, 0.0, 11.0, 11.0, 21.0, 0.0]        9
# 4   [174.2, 4.0, 24.0, 1.0, 15.0, 1.0, 10.0]       10
#
#                                          ingredients  calories
# 0  ['winter squash', 'mexican seasoning', 'mixed ...      51.5
# 1  ['tomato juice', 'apple cider vinegar', 'sugar...     352.9
# 2  ['fennel seeds', 'green olives', 'ripe olives'...     380.7
# 3  ['egg roll wrap', 'whole green chilies', 'chee...      94.0
# 4  ['canola oil', 'onion', 'garlic', 'cauliflower...     174.2
# Optimized recipes saved at: ../data/optimized_recipes.csv
#
# Top 5 Optimized Recipes:
#            id                              name  minutes  \
# 2074    69347                     baked walleye       30
# 16638  309755                  marinated olives       10
# 16917   52580  mediterranean roasted vegetables       80
# 16824   26500          mc donald s secret sauce       60
# 9427   204977     eggplant  aubergine  croutons       35
#
#                                                     tags  \
# 2074   ['30-minutes-or-less', 'time-to-make', 'course...
# 16638  ['15-minutes-or-less', 'time-to-make', 'course...
# 16917  ['weeknight', 'time-to-make', 'course', 'main-...
# 16824  ['60-minutes-or-less', 'time-to-make', 'course...
# 9427   ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                      nutrition  n_steps  \
# 2074   [156.8, 26.0, 1.0, 6.0, 0.0, 54.0, 0.0]        5
# 16638     [38.3, 5.0, 0.0, 8.0, 0.0, 2.0, 0.0]        4
# 16917   [131.3, 21.0, 0.0, 0.0, 0.0, 9.0, 0.0]       10
# 16824     [20.7, 2.0, 7.0, 2.0, 0.0, 1.0, 0.0]        2
# 9427   [240.2, 41.0, 0.0, 0.0, 0.0, 18.0, 0.0]       11
#
#                                              ingredients  calories  \
# 2074   ['walleyed pike fillet', 'butter', 'lemon juic...     156.8
# 16638  ['oil-cured black olives', 'olive oil', 'garli...      38.3
# 16917  ['vidalia onion', 'eggplant', 'bell pepper', '...     131.3
# 16824  ['mayonnaise', 'relish', 'sugar', 'thousand is...      20.7
# 9427   ['japanese eggplants', 'salt', 'olive oil', 'p...     240.2
#
#        nutrition_calories  total_fat  sugar  sodium  protein  saturated_fat  \
# 2074                156.8       26.0    1.0     6.0      0.0           54.0
# 16638                38.3        5.0    0.0     8.0      0.0            2.0
# 16917               131.3       21.0    0.0     0.0      0.0            9.0
# 16824                20.7        2.0    7.0     2.0      0.0            1.0
# 9427                240.2       41.0    0.0     0.0      0.0           18.0
#
#        carbohydrates  total_macros  total_fat_percentage  protein_percentage  \
# 2074             0.0          26.0                   1.0                 0.0
# 16638            0.0           5.0                   1.0                 0.0
# 16917            0.0          21.0                   1.0                 0.0
# 16824            0.0           2.0                   1.0                 0.0
# 9427             0.0          41.0                   1.0                 0.0
#
#        carbohydrates_percentage  fitness_score
# 2074                        0.0            0.5
# 16638                       0.0            0.5
# 16917                       0.0            0.5
# 16824                       0.0            0.5
# 9427                        0.0            0.5
